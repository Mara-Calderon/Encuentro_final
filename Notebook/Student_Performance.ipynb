# %% [markdown]
# ## Grupo encuentro final
# - Mara Alejandra Calderón Diaz
# - Magalys del Carmen Camargo

# %% [markdown]
# # Introducción
# Estos datos abordan el rendimiento de los alumnos en educación secundaria de dos centros escolares portugueses. Los atributos de los datos incluyen calificaciones de los estudiantes, características demográficas, sociales y relacionadas con la escuela) y se recopilaron mediante el uso de informes y cuestionarios escolares. Se proporcionan dos conjuntos de datos sobre el desempeño en dos materias distintas: Matemáticas (mat) y lengua portuguesa (por).
#
# Este data set esta compuesto por las siguientes variables:
# - school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# - sex - student's sex (binary: 'F' - female or 'M' - male)
# - age - student's age (numeric: from 15 to 22)
# - address - student's home address type (binary: 'U' - urban or 'R' - rural)
# - famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# - Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# - Medu - mother's education (numeric: 0 - none,  1 - primary education (4th grade), 2 â€“ 5th to 9th grade, 3 â€“ secondary education or 4 â€“ higher education)
# - Fedu - father's education (numeric: 0 - none,  1 - primary education (4th grade), 2 â€“ 5th to 9th grade, 3 â€“ secondary education or 4 â€“ higher education)
# - Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# - Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# - reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# - guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# - traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# - studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# - failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# - schoolsup - extra educational support (binary: yes or no)
# - famsup - family educational support (binary: yes or no)
# - paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# - activities - extra-curricular activities (binary: yes or no)
# - nursery - attended nursery school (binary: yes or no)
# - higher - wants to take higher education (binary: yes or no)
# - internet - Internet access at home (binary: yes or no)
# - romantic - with a romantic relationship (binary: yes or no)
# - famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# - freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# - goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# - Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# - Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# - health - current health status (numeric: from 1 - very bad to 5 - very good)
# - absences - number of school absences (numeric: from 0 to 93)
#
# #### Estas calificaciones están relacionadas con la materia del curso, Matemáticas o Portugués:
# - G1 - first period grade (numeric: from 0 to 20)
# - G2 - second period grade (numeric: from 0 to 20)
# - G3 - final grade (numeric: from 0 to 20, output target)
#
# ## Objetivo
# Realizar un análisis del rendimiento de los estudiantes ligado a su entorno familiar y a el uso del tiempo libre del estudiante.

# %%
# Importar librerias a usar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Convertir información en un data set de pandas
dfm=pd.read_csv('../Data/student-mat.csv',sep=';')
# Visualizar primeros 5 registros
dfm.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
# Información general del dataset
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
# Convertir información en un data set de pandas
dfp=pd.read_csv('../Data/student-por.csv',sep=';')
# Visualizar primeros 5 registros
dfp.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
# Información general del dataset
dfp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
# Verificar tipo de información
print(dfm.shape)
print(dfp.shape)
print(dfm.columns)
print(dfp.columns)
# Out:
# (395, 33)
# (649, 33)
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
# Agregar columna materia
dfm['materia'] = 'Mate'
dfp['materia'] = 'Port'
# Unir las bases
df = pd.concat([dfm, dfp], ignore_index=True)
print(df.shape)

# Comprobar unión de bases
print(df['materia'].value_counts())
# Out:
# (1044, 34)
# materia
# Port    649
# Mate    395
# Name: count, dtype: int64

# %%
# Validacion informacion dataframe concatenado

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      1044 non-null   object
#  1   sex         1044 non-null   object
#  2   age         1044 non-null   int64
#  3   address     1044 non-null   object
#  4   famsize     1044 non-null   object
#  5   Pstatus     1044 non-null   object
#  6   Medu        1044 non-null   int64
#  7   Fedu        1044 non-null   int64
#  8   Mjob        1044 non-null   object
#  9   Fjob        1044 non-null   object
#  10  reason      1044 non-null   object
#  11  guardian    1044 non-null   object
#  12  traveltime  1044 non-null   int64
#  13  studytime   1044 non-null   int64
#  14  failures    1044 non-null   int64
#  15  schoolsup   1044 non-null   object
#  16  famsup      1044 non-null   object
#  17  paid        1044 non-null   object
#  18  activities  1044 non-null   object
# ...

# %%
# Realizar promedio de los 3 periodos
df['promedio'] = (df['G1'] + df['G2'] + df['G3']) / 3

# %%
# Declarar variable
bajo = 12
medio = 16
alto = 20

# Filtrar base de datos extrayendo estudiantes con promedios inferios a 12
df_baj = df.loc[df['promedio'] < bajo]
# Filtrar base de datos extrayendo estudiantes con promedios entre 12 a 16
df_med = df.loc[(df['promedio'] >= bajo) & (df['promedio'] < medio)]
# Filtrar base de datos extrayendo estudiantes con promedios entre 16 a 20
df_alt = df.loc[(df['promedio'] >= medio) & (df['promedio'] <= alto)]

# %%
# Actividades extracurriculares promedio bajo
print("Actividades extracurriculares promedio bajo\n",df_baj['activities'].value_counts(normalize= True)*100)
# Actividades extracurriculares promedio medio
print("Actividades extracurriculares promedio medio\n",df_med['activities'].value_counts(normalize= True)*100)
# Actividades extracurriculares promedio alto
print("Actividades extracurriculares promedio alto\n",df_alt['activities'].value_counts(normalize= True)*100)
# Out:
# Actividades extracurriculares promedio bajo
#  activities
# no     53.151618
# yes    46.848382
# Name: proportion, dtype: float64
# Actividades extracurriculares promedio medio
#  activities
# yes    52.755906
# no     47.244094
# Name: proportion, dtype: float64
# Actividades extracurriculares promedio alto
#  activities
# yes    52.631579
# no     47.368421
# Name: proportion, dtype: float64

# %% [markdown]
# - No se encuentra evidencia de impacto entre la realización de actividades extracurriculares y el rendimiento academico.

# %%
# Tiempo libre despues del estudio promedio bajo
print("Tiempo libre despues del estudio promedio bajo\n",df_baj['freetime'].value_counts(normalize= True)*100)
# Tiempo libre despues del estudio promedio medio
print("Tiempo libre despues del estudio promedio medio\n",df_med['freetime'].value_counts(normalize= True)*100)
# Tiempo libre despues del estudio promedio alto
print("Tiempo libre despues del estudio promedio alto\n",df_alt['freetime'].value_counts(normalize= True)*100)
# Out:
# Tiempo libre despues del estudio promedio bajo
#  freetime
# 3    39.011925
# 4    28.620102
# 2    14.139693
# 5    11.413969
# 1     6.814310
# Name: proportion, dtype: float64
# Tiempo libre despues del estudio promedio medio
#  freetime
# 3    40.944882
# 4    27.559055
# 2    18.372703
# 5     8.136483
# 1     4.986877
# Name: proportion, dtype: float64
# Tiempo libre despues del estudio promedio alto
#  freetime
# 3    30.263158
# 4    26.315789
# 2    23.684211
# 5    13.157895
# 1     6.578947
# Name: proportion, dtype: float64

# %% [markdown]
# - No se encuentra evidencia de impacto entre tiempo libre despues del estudio y el rendimiento academico.

# %%
# Definir una paleta de colores
palette = {"yes": "blue", "no": "orange"}

# Crear una figura con dos subgráficas
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Gráfico para los sobrevivientes
sns.histplot(data=df[df['school'] == 'GP'], x='promedio', hue='famsup', bins=30, kde=True, ax=axes[0], palette=palette, alpha=0.7)
axes[0].set_title('Distribución del Promedio academico Escuela GP')
axes[0].set_xlabel('Promedio')
axes[0].set_ylabel('Frecuencia')

# Gráfico para los no sobrevivientes
sns.histplot(data=df[df['school'] == 'MS'], x='promedio', hue='famsup', bins=30, kde=True, ax=axes[1], palette=palette, alpha=0.7)
axes[1].set_title('Distribución del Promedio academico Escuela MS')
axes[1].set_xlabel('Promedio')
axes[1].set_ylabel('Frecuencia')

# Ajustar el espacio entre los gráficos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# - Se identifica que la mayoría de estudiantes cuenta con apoyo familiar en la educación. No obstante, no hay un impacto significativo en el rendimiento académico
# - Se identifica que los estudiantes que asisten a la academia Gabriel Pereira tienen mejor promedio

# %%
# Definir una paleta de colores
palette = {"yes": "blue", "no": "orange"}

# Crear una figura con dos subgráficas
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Gráfico para los sobrevivientes
sns.histplot(data=df[df['school'] == 'GP'], x='promedio', hue='higher', bins=30, kde=True, ax=axes[0], palette=palette, alpha=0.7)
axes[0].set_title('Distribución del Promedio academico Escuela GP')
axes[0].set_xlabel('Promedio')
axes[0].set_ylabel('Frecuencia')

# Gráfico para los no sobrevivientes
sns.histplot(data=df[df['school'] == 'MS'], x='promedio', hue='higher', bins=30, kde=True, ax=axes[1], palette=palette, alpha=0.7)
axes[1].set_title('Distribución del Promedio academico Escuela MS')
axes[1].set_xlabel('Promedio')
axes[1].set_ylabel('Frecuencia')

# Ajustar el espacio entre los gráficos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# - Se identifica que la mayoría de estudiantes quieren cursar una educación superior. No obstante, se evidencia poco impacto sobre el rendimiento académico

# %%
# Validacion si la convivencia influye en el rendimiento

print("Estado de convivencia de los padres en rendimiento bajo\n",df_baj['Pstatus'].value_counts( normalize= True)*100)
# Actividades extracurriculares promedio medio
print("Estado de convivencia de los padres en rendimiento medio\n",df_med['Pstatus'].value_counts(normalize= True)*100)
# Actividades extracurriculares promedio alto
print("Estado de convivencia de los padres en rendimiento alto\n",df_alt['Pstatus'].value_counts(normalize= True)*100)
# Out:
# Estado de convivencia de los padres en rendimiento bajo
#  Pstatus
# T    88.586031
# A    11.413969
# Name: proportion, dtype: float64
# Estado de convivencia de los padres en rendimiento medio
#  Pstatus
# T    88.451444
# A    11.548556
# Name: proportion, dtype: float64
# Estado de convivencia de los padres en rendimiento alto
#  Pstatus
# T    86.842105
# A    13.157895
# Name: proportion, dtype: float64

# %% [markdown]
# En este caso se concluye que estado de convivencia no influye directamente en el rendimiento escolar, debido a que se presenta un comportamiento similar en los diferentes promedios bajo, medio y alto

# %%
#

#crear una cuadrícula de 2x2 para los boxplots
fig ,  axes  =  plt . subplots ( 1 ,  2 ,  figsize = ( 12 ,  6 ))

# Como el trabajo del padre y de la madre que influyen en en el rendimiento

sns.boxplot(x="Fjob", y="promedio", hue="sex", data=df,  ax = axes [ 0 ])
axes [ 0 ] .set_title ( 'Distribución promedio del trabajo del padre')

sns.boxplot(x="Mjob", y="promedio", hue="sex", data=df, ax = axes [ 1 ])
axes [ 1 ] .set_title ( 'Distribución promedio del trabajo de la madre')

# ajustar el espacio entre subgráficas
plt.tight_layout(pad=5)
plt.show()

# %%
# crear una cuadrícula de 2x2 para los boxplots
fig ,  axes  =  plt . subplots ( 1 ,  2 ,  figsize = ( 12 ,  6 ))


# graficar cada boxplot en su respectiva subgráfica
sns . boxplot( x = 'Medu' ,  y = 'promedio' ,  data = df ,  ax = axes [ 0 ])
axes [ 0 ] . set_title ( 'Distribución promedio de acuerdo nivel educativo madre')


sns . boxplot( x = 'Fedu' ,  y = 'promedio' ,  data = df ,  ax = axes [ 1 ])
axes[ 1 ] . set_title ( 'Distribución de promedio de acuerdo nivel educativo de los padre')

# ajustar el espacio entre subgráficas
plt.tight_layout(pad=4)
plt.show()
